# %% [markdown]
# <a href="https://colab.research.google.com/github/CM-007/pythonCode_DS/blob/main/DataStructurePandasClass.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import

# %%
import pandas as pd

# %%
dir(pd)
# Out:
# ['ArrowDtype',
#  'BooleanDtype',
#  'Categorical',
#  'CategoricalDtype',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'DatetimeTZDtype',
#  'ExcelFile',
#  'ExcelWriter',
#  'Flags',
#  'Float32Dtype',
#  'Float64Dtype',
#  'Float64Index',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int16Dtype',
#  'Int32Dtype',
#  'Int64Dtype',
#  'Int64Index',
#  'Int8Dtype',
#  'Interval',
#  'IntervalDtype',
#  'IntervalIndex',
#  'MultiIndex',
#  'NA',
#  'NaT',
#  'NamedAgg',
#  'Period',
#  'PeriodDtype',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseDtype',
#  'StringDtype',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt16Dtype',
#  'UInt32Dtype',
#  'UInt64Dtype',
#  'UInt64Index',
#  'UInt8Dtype',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__deprecated_num_index_names',
#  '__dir__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__getattr__',
#  '__git_version__',
#  '__loader__',
# ...

# %% [markdown]
# Read CSV file

# %%
# comma seprated value -csv
df=pd.read_csv("/content/sample_data/california_housing_train.csv")

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %%
df.tail()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
#        population  households  median_income  median_house_value
# 16995       907.0       369.0         2.3571            111400.0
# 16996      1194.0       465.0         2.5179             79000.0
# 16997      1244.0       456.0         3.0313            103600.0
# 16998      1298.0       478.0         1.9797             85800.0
# 16999       806.0       270.0         3.0147             94600.0

# %%
# df=pd.read_csv("/content/Salaries.csv")
df=pd.read_csv("Salaries.csv")

# %%
df.columns
# Out:
# Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')

# %%
df.head()
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800

# %%
df.tail()
# Out:
#          rank discipline  phd  service     sex  salary
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.dtypes
# Out:
# rank          object
# discipline    object
# phd            int64
# service        int64
# sex           object
# salary         int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   rank        78 non-null     object
#  1   discipline  78 non-null     object
#  2   phd         78 non-null     int64
#  3   service     78 non-null     int64
#  4   sex         78 non-null     object
#  5   salary      78 non-null     int64
# dtypes: int64(3), object(3)
# memory usage: 3.8+ KB

# %%
# df.rank
df['rank']
# Out:
# 0          Prof
# 1          Prof
# 2          Prof
# 3          Prof
# 4          Prof
#         ...
# 73         Prof
# 74    AssocProf
# 75         Prof
# 76         Prof
# 77         Prof
# Name: rank, Length: 78, dtype: object

# %%
df.describe()
# Out:
#              phd    service         salary
# count  78.000000  78.000000      78.000000
# mean   19.705128  15.051282  108023.782051
# std    12.498425  12.139768   28293.661022
# min     1.000000   0.000000   57800.000000
# 25%    10.250000   5.250000   88612.500000
# 50%    18.500000  14.500000  104671.000000
# 75%    27.750000  20.750000  126774.750000
# max    56.000000  51.000000  186960.000000

# %%
df.min()
# Out:
# rank          AssocProf
# discipline            A
# phd                   1
# service               0
# sex              Female
# salary            57800
# dtype: object

# %%
df.max()
# Out:
# rank            Prof
# discipline         B
# phd               56
# service           51
# sex             Male
# salary        186960
# dtype: object

# %%
df.mean()
# Out:
# <ipython-input-17-c61f0c8f89b5>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# phd            19.705128
# service        15.051282
# salary     108023.782051
# dtype: float64

# %%
# df.phd.describe()
df['phd'].describe()
# Out:
# count    78.000000
# mean     19.705128
# std      12.498425
# min       1.000000
# 25%      10.250000
# 50%      18.500000
# 75%      27.750000
# max      56.000000
# Name: phd, dtype: float64

# %%
df.salary.quantile(0.10)
# Out:
# 73440.0

# %%
df.std()
# Out:
# <ipython-input-20-ce97bb7eaef8>:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.std()
# phd           12.498425
# service       12.139768
# salary     28293.661022
# dtype: float64

# %%
df.head(20).mean()
# Out:
# <ipython-input-21-401e2f7d3f9d>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.head(20).mean()
# phd            24.45
# service        19.85
# salary     117545.85
# dtype: float64

# %% [markdown]
# # selecting a column

# %%
df.salary
# Out:
# 0     186960
# 1      93000
# 2     110515
# 3     131205
# 4     104800
#        ...
# 73    105450
# 74    104542
# 75    124312
# 76    109954
# 77    109646
# Name: salary, Length: 78, dtype: int64

# %%
df['salary']
# Out:
# 0     186960
# 1      93000
# 2     110515
# 3     131205
# 4     104800
#        ...
# 73    105450
# 74    104542
# 75    124312
# 76    109954
# 77    109646
# Name: salary, Length: 78, dtype: int64

# %%
result1=df.salary
result1
# Out:
# 0     186960
# 1      93000
# 2     110515
# 3     131205
# 4     104800
#        ...
# 73    105450
# 74    104542
# 75    124312
# 76    109954
# 77    109646
# Name: salary, Length: 78, dtype: int64

# %%
type(result1)
# Out:
# pandas.core.series.Series

# %%
type(df.phd)
# Out:
# pandas.core.series.Series

# %%
result2=df[['salary','rank']]

# %%
type(result2)
# Out:
# pandas.core.frame.DataFrame

# %%
newdf=df[['salary','service','phd']]
newdf
# Out:
#     salary  service  phd
# 0   186960       49   56
# 1    93000        6   12
# 2   110515       20   23
# 3   131205       31   40
# 4   104800       18   20
# ..     ...      ...  ...
# 73  105450       10   18
# 74  104542        6   19
# 75  124312       17   17
# 76  109954       14   28
# 77  109646       15   23
#
# [78 rows x 3 columns]

# %%
df['discipline'].value_counts()
# Out:
# B    42
# A    36
# Name: discipline, dtype: int64

# %%
df.sex.value_counts()
# Out:
# Male      39
# Female    39
# Name: sex, dtype: int64

# %%
df['rank'].value_counts()
# Out:
# Prof         46
# AsstProf     19
# AssocProf    13
# Name: rank, dtype: int64

# %%
df['phd'].describe()
# Out:
# count    78.000000
# mean     19.705128
# std      12.498425
# min       1.000000
# 25%      10.250000
# 50%      18.500000
# 75%      27.750000
# max      56.000000
# Name: phd, dtype: float64

# %%
df['phd'].count()
# Out:
# 78

# %%
df['phd'].mean()
# Out:
# 19.705128205128204

# %%
df.groupby(['rank']).mean()
# Out:
# <ipython-input-36-59c8c915524f>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['rank']).mean()
#                  phd    service         salary
# rank
# AssocProf  15.076923  11.307692   91786.230769
# AsstProf    5.052632   2.210526   81362.789474
# Prof       27.065217  21.413043  123624.804348

# %%
df.groupby(['sex']).mean()
# Out:
# <ipython-input-37-f1f0eb4b7e52>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['sex']).mean()
#               phd    service         salary
# sex
# Female  16.512821  11.564103  101002.410256
# Male    22.897436  18.538462  115045.153846

# %%
df.groupby(['sex']).max()
# Out:
#         rank discipline  phd  service  salary
# sex
# Female  Prof          B   39       36  161101
# Male    Prof          B   56       51  186960

# %%
df.groupby(['rank']).count()
# Out:
#            discipline  phd  service  sex  salary
# rank
# AssocProf          13   13       13   13      13
# AsstProf           19   19       19   19      19
# Prof               46   46       46   46      46

# %%
df.groupby(['discipline']).mean()
# Out:
# <ipython-input-39-c0256a7a69fd>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['discipline']).mean()
#                   phd    service         salary
# discipline
# A           21.527778  15.722222   98331.111111
# B           18.142857  14.476190  116331.785714

# %%
df.groupby(['discipline','rank']).count()
# Out:
#                       phd  service  sex  salary
# discipline rank
# A          AssocProf    5        5    5       5
#            AsstProf     8        8    8       8
#            Prof        23       23   23      23
# B          AssocProf    8        8    8       8
#            AsstProf    11       11   11      11
#            Prof        23       23   23      23

# %%
df.groupby(['discipline','rank','sex']).count()
# Out:
#                              phd  service  salary
# discipline rank      sex
# A          AssocProf Female    4        4       4
#                      Male      1        1       1
#            AsstProf  Female    6        6       6
#                      Male      2        2       2
#            Prof      Female    8        8       8
#                      Male     15       15      15
# B          AssocProf Female    6        6       6
#                      Male      2        2       2
#            AsstProf  Female    5        5       5
#                      Male      6        6       6
#            Prof      Female   10       10      10
#                      Male     13       13      13

# %%
df.groupby('rank')[['salary','phd']].mean()
# Out:
#                   salary        phd
# rank
# AssocProf   91786.230769  15.076923
# AsstProf    81362.789474   5.052632
# Prof       123624.804348  27.065217

# %%
g=df.groupby('rank')

# %%
for i in g:
  print(i)
# Out:
# ('AssocProf',          rank discipline  phd  service     sex  salary
# 6   AssocProf          A   20       17    Male   81285
# 30  AssocProf          B    9        7    Male  107008
# 34  AssocProf          B   12        8    Male  119800
# 41  AssocProf          A   13        8  Female   74830
# 47  AssocProf          B   11       11  Female  103613
# 54  AssocProf          A   25       22  Female   62884
# 56  AssocProf          A   10        8  Female   77500
# 59  AssocProf          B   12       10  Female  103994
# 61  AssocProf          B   13       10  Female  103750
# 62  AssocProf          B   14        7  Female  109650
# 64  AssocProf          A   26       24  Female   73300
# 71  AssocProf          B   12        9  Female   71065
# 74  AssocProf          B   19        6  Female  104542)
# ('AsstProf',         rank discipline  phd  service     sex  salary
# 12  AsstProf          B    1        0    Male   88000
# 16  AsstProf          B    8        3    Male   75044
# ...

# %%
df[df.salary>180000]
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960

# %%
df.shape #(row,column)[0,1]
# Out:
# (78, 6)

# %%
df[df.salary>120000].shape[0]
# Out:
# 25

# %%
df[df.salary>120000].value_counts()
# Out:
# rank  discipline  phd  service  sex     salary
# Prof  A           18   18       Male    126300    1
#       B           22   21       Male    155750    1
#                   45   45       Male    146856    1
#                   39   33       Male    128250    1
#                   36   26       Female  144651    1
#                   35   33       Male    162200    1
#                   28   23       Male    126933    1
#                   25   25       Female  140096    1
#                        19       Male    153750    1
#                   24   15       Female  161101    1
#                   23   23       Male    134778    1
#                        19       Female  151768    1
#                   21   20       Male    123683    1
#       A           20   20       Male    122400    1
#       B           20   14       Female  127512    1
#                   18   18       Female  129000    1
#                   17   18       Female  122960    1
# ...

# %%
df[df.salary>10000].shape[0]
# Out:
# 78

# %%
newdf=df[(df.sex=='Male') & (df.salary > 150000)]
newdf
# Out:
#     rank discipline  phd  service   sex  salary
# 0   Prof          B   56       49  Male  186960
# 13  Prof          B   35       33  Male  162200
# 14  Prof          B   25       19  Male  153750
# 15  Prof          B   17        3  Male  150480
# 19  Prof          A   29       27  Male  150500
# 27  Prof          A   45       43  Male  155865
# 31  Prof          B   22       21  Male  155750

# %%
newdf=df[(df['sex']=='Male') & (df['salary'] > 150000)]
newdf
# Out:
#     rank discipline  phd  service   sex  salary
# 0   Prof          B   56       49  Male  186960
# 13  Prof          B   35       33  Male  162200
# 14  Prof          B   25       19  Male  153750
# 15  Prof          B   17        3  Male  150480
# 19  Prof          A   29       27  Male  150500
# 27  Prof          A   45       43  Male  155865
# 31  Prof          B   22       21  Male  155750

# %%
newdf.count()
# Out:
# rank          7
# discipline    7
# phd           7
# service       7
# sex           7
# salary        7
# dtype: int64

# %%
newdf.shape[0]
# Out:
# 7

# %%
df[df['rank'] != 'Prof'].shape[0]
# Out:
# 32

# %%
df[(df['service']>15) | (df['salary']>10000)].shape[0]
# Out:
# 78

# %%
df[df['service']>15]
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 19       Prof          A   29       27    Male  150500
# 21       Prof          A   33       30    Male  103106
# 24       Prof          A   30       23    Male   91100
# ...

# %% [markdown]
# ## **iloc -- index column**

# %%
df.iloc[5]
# Out:
# rank            Prof
# discipline         A
# phd               20
# service           20
# sex             Male
# salary        122400
# Name: 5, dtype: object

# %%
df.iloc[1:4 , 0:2]
# Out:
#    rank discipline
# 1  Prof          A
# 2  Prof          A
# 3  Prof          A

# %%
df.iloc[:9]
# Out:
#         rank discipline  phd  service   sex  salary
# 0       Prof          B   56       49  Male  186960
# 1       Prof          A   12        6  Male   93000
# 2       Prof          A   23       20  Male  110515
# 3       Prof          A   40       31  Male  131205
# 4       Prof          B   20       18  Male  104800
# 5       Prof          A   20       20  Male  122400
# 6  AssocProf          A   20       17  Male   81285
# 7       Prof          A   18       18  Male  126300
# 8       Prof          A   29       19  Male   94350

# %%
df.iloc[[12,34,32,11,31,22]]
# Out:
#          rank discipline  phd  service   sex  salary
# 12   AsstProf          B    1        0  Male   88000
# 34  AssocProf          B   12        8  Male  119800
# 32       Prof          A   27       19  Male  103275
# 11       Prof          B   23       23  Male  134778
# 31       Prof          B   22       21  Male  155750
# 22   AsstProf          A    4        2  Male   73000

# %% [markdown]
# # **Aggregation function **

# %%
df[['phd','salary']].agg(['min','mean','max','mad','std'])
# Out:
# <ipython-input-75-c7b8e02415f2>:1: FutureWarning: The 'mad' method is deprecated and will be removed in a future version. To compute the same result, you may do `(df - df.mean()).abs().mean()`.
#   df[['phd','salary']].agg(['min','mean','max','mad','std'])
# <ipython-input-75-c7b8e02415f2>:1: FutureWarning: The 'mad' method is deprecated and will be removed in a future version. To compute the same result, you may do `(df - df.mean()).abs().mean()`.
#   df[['phd','salary']].agg(['min','mean','max','mad','std'])
#             phd         salary
# min    1.000000   57800.000000
# mean  19.705128  108023.782051
# max   56.000000  186960.000000
# mad    9.920776   22957.266930
# std   12.498425   28293.661022

# %%
df[['salary']].agg('skew')
# Out:
# salary    0.452103
# dtype: float64

# %%
df.var()
# Out:
# <ipython-input-78-28ded241fd7c>:1: FutureWarning: The default value of numeric_only in DataFrame.var is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.var()
# phd        1.562106e+02
# service    1.473740e+02
# salary     8.005313e+08
# dtype: float64
